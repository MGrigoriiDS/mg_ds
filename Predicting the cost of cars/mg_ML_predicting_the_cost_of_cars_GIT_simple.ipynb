# %% [markdown]
# # Predicting the cost of cars

# %% [markdown]
# ## Introduction

# %% [markdown]
# The service for the sale of used cars is developing an application to attract new customers. In it, you can quickly find out the market value of your car. Historical data is at your disposal: technical specifications, complete sets and prices of cars. You need to build a model to determine the cost.

# %% [markdown]
# ## Important to the customer:
#
# - prediction quality;
# - prediction speed;
# - training time.

# %% [markdown]
# ## Data description:
# Признаки:
# - `DateCrawled` — date the questionnaire was downloaded from the database
# - 'VehicleType` — type of car body
# - 'registrationyear` — the year of registration of the car
# - 'Gearbox` — type of gearbox
# - 'Power` - power (hp)
# - 'Model` - car model
# - 'Kilometer` - mileage (km)
# - 'Registrationmonth` — month of car registration
# - 'FuelType` — fuel type
# - 'Brand` — car brand
# - 'notrepaired` — was the car under repair or not
# - 'DateCreated` — date the questionnaire was created
# - 'numberofpictures` — number of photos of the car
# - 'Postalcode` — postal code of the questionnaire owner (user)
# - 'lastSeen` — the date of the user's last activity
#
# Target attribute:
# - 'Price` - price (Euro)

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
from lightgbm import LGBMRegressor
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split, RepeatedKFold, cross_val_score
from sklearn.metrics import mean_squared_error as mse, make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesClassifier

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Data Loading

# %%
# Upload the data and create a dataframe

df = pd.read_csv('autos.csv')
df
# Out:
#                 DateCrawled  Price  VehicleType  RegistrationYear Gearbox  \
# 0       2016-03-24 11:52:17    480          NaN              1993  manual
# 1       2016-03-24 10:58:45  18300        coupe              2011  manual
# 2       2016-03-14 12:52:21   9800          suv              2004    auto
# 3       2016-03-17 16:54:04   1500        small              2001  manual
# 4       2016-03-31 17:25:20   3600        small              2008  manual
# ...                     ...    ...          ...               ...     ...
# 354364  2016-03-21 09:50:58      0          NaN              2005  manual
# 354365  2016-03-14 17:48:27   2200          NaN              2005     NaN
# 354366  2016-03-05 19:56:21   1199  convertible              2000    auto
# 354367  2016-03-19 18:57:12   9200          bus              1996  manual
# 354368  2016-03-20 19:41:08   3400        wagon              2002  manual
#
#         Power        Model  Kilometer  RegistrationMonth  FuelType  \
# 0           0         golf     150000                  0    petrol
# 1         190          NaN     125000                  5  gasoline
# 2         163        grand     125000                  8  gasoline
# 3          75         golf     150000                  6    petrol
# 4          69        fabia      90000                  7  gasoline
# ...       ...          ...        ...                ...       ...
# 354364      0         colt     150000                  7    petrol
# 354365      0          NaN      20000                  1       NaN
# 354366    101       fortwo     125000                  3    petrol
# 354367    102  transporter     150000                  3  gasoline
# 354368    100         golf     150000                  6  gasoline
#
#                  Brand NotRepaired          DateCreated  NumberOfPictures  \
# 0           volkswagen         NaN  2016-03-24 00:00:00                 0
# 1                 audi         yes  2016-03-24 00:00:00                 0
# 2                 jeep         NaN  2016-03-14 00:00:00                 0
# 3           volkswagen          no  2016-03-17 00:00:00                 0
# 4                skoda          no  2016-03-31 00:00:00                 0
# ...                ...         ...                  ...               ...
# 354364      mitsubishi         yes  2016-03-21 00:00:00                 0
# 354365  sonstige_autos         NaN  2016-03-14 00:00:00                 0
# 354366           smart          no  2016-03-05 00:00:00                 0
# 354367      volkswagen          no  2016-03-19 00:00:00                 0
# 354368      volkswagen         NaN  2016-03-20 00:00:00                 0
#
#         PostalCode             LastSeen
# 0            70435  2016-04-07 03:16:57
# 1            66954  2016-04-07 01:46:50
# 2            90480  2016-04-05 12:47:46
# 3            91074  2016-03-17 17:40:17
# 4            60437  2016-04-06 10:17:21
# ...            ...                  ...
# 354364        2694  2016-03-21 10:42:49
# 354365       39576  2016-04-06 00:46:52
# 354366       26135  2016-03-11 18:17:12
# 354367       87439  2016-04-07 07:15:26
# 354368       40764  2016-03-24 12:45:21
#
# [354369 rows x 16 columns]

# %% [markdown]
# ### Diving into the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Kilometer          354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %%
df.describe()
# Out:
#                Price  RegistrationYear          Power      Kilometer  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %%
df.dtypes
# Out:
# DateCrawled          object
# Price                 int64
# VehicleType          object
# RegistrationYear      int64
# Gearbox              object
# Power                 int64
# Model                object
# Kilometer             int64
# RegistrationMonth     int64
# FuelType             object
# Brand                object
# NotRepaired          object
# DateCreated          object
# NumberOfPictures      int64
# PostalCode            int64
# LastSeen             object
# dtype: object

# %%
# Check for duplicates

df.duplicated().sum()
# Out:
# 4

# %% [markdown]
# * There are duplicates in the data. Date columns have a string type. We will remove unnecessary columns, study omissions, remove duplicates, and bring the signs to the desired format.

# %%
# Remove duplicates

df = df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Remove the columns that do not affect the price of the car

df = df.drop(['DateCrawled', 'DateCreated', 'NumberOfPictures', 'PostalCode', 'LastSeen'], axis=1)
df
# Out:
#         Price  VehicleType  RegistrationYear Gearbox  Power        Model  \
# 0         480          NaN              1993  manual      0         golf
# 1       18300        coupe              2011  manual    190          NaN
# 2        9800          suv              2004    auto    163        grand
# 3        1500        small              2001  manual     75         golf
# 4        3600        small              2008  manual     69        fabia
# ...       ...          ...               ...     ...    ...          ...
# 354360      0          NaN              2005  manual      0         colt
# 354361   2200          NaN              2005     NaN      0          NaN
# 354362   1199  convertible              2000    auto    101       fortwo
# 354363   9200          bus              1996  manual    102  transporter
# 354364   3400        wagon              2002  manual    100         golf
#
#         Kilometer  RegistrationMonth  FuelType           Brand NotRepaired
# 0          150000                  0    petrol      volkswagen         NaN
# 1          125000                  5  gasoline            audi         yes
# 2          125000                  8  gasoline            jeep         NaN
# 3          150000                  6    petrol      volkswagen          no
# 4           90000                  7  gasoline           skoda          no
# ...           ...                ...       ...             ...         ...
# 354360     150000                  7    petrol      mitsubishi         yes
# 354361      20000                  1       NaN  sonstige_autos         NaN
# 354362     125000                  3    petrol           smart          no
# 354363     150000                  3  gasoline      volkswagen          no
# 354364     150000                  6  gasoline      volkswagen         NaN
#
# [354365 rows x 11 columns]

# %%
# Let's check the missing value percentages in the dataset now.

pd.DataFrame(round((df.isna().mean()*100),2)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_d97c1_row0_col0, #T_d97c1_row2_col0, #T_d97c1_row4_col0, #T_d97c1_row6_col0, #T_d97c1_row7_col0, #T_d97c1_row9_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d97c1_row1_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_d97c1_row3_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d97c1_row5_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_d97c1_row8_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_d97c1_row10_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d97c1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d97c1_level0_row0" class="row_heading level0 row0" >Price</th>
#       <td id="T_d97c1_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row1" class="row_heading level0 row1" >VehicleType</th>
#       <td id="T_d97c1_row1_col0" class="data row1 col0" >10.580000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row2" class="row_heading level0 row2" >RegistrationYear</th>
#       <td id="T_d97c1_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row3" class="row_heading level0 row3" >Gearbox</th>
#       <td id="T_d97c1_row3_col0" class="data row3 col0" >5.600000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row4" class="row_heading level0 row4" >Power</th>
#       <td id="T_d97c1_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row5" class="row_heading level0 row5" >Model</th>
#       <td id="T_d97c1_row5_col0" class="data row5 col0" >5.560000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row6" class="row_heading level0 row6" >Kilometer</th>
#       <td id="T_d97c1_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row7" class="row_heading level0 row7" >RegistrationMonth</th>
#       <td id="T_d97c1_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row8" class="row_heading level0 row8" >FuelType</th>
#       <td id="T_d97c1_row8_col0" class="data row8 col0" >9.280000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row9" class="row_heading level0 row9" >Brand</th>
#       <td id="T_d97c1_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d97c1_level0_row10" class="row_heading level0 row10" >NotRepaired</th>
#       <td id="T_d97c1_row10_col0" class="data row10 col0" >20.080000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * There are missing value in the columns: Vehicle Type, Gearbox, Model, FuelType, NotRepaired. All these signs are individual. It would be incorrect to assume what type of body - sedan or hatchback, automatic transmission or mechanics, model, fuel type and whether there was a repair. Fill in the missing value with the value "unknown".

# %%
# Fill in the missing value with the value "unknown"

df = df.fillna('unknown')

# %%
# Let's check if there are any missing value in our data after filling in

pd.DataFrame(round((df.isna().mean()*100),2)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_ea27d_row0_col0, #T_ea27d_row1_col0, #T_ea27d_row2_col0, #T_ea27d_row3_col0, #T_ea27d_row4_col0, #T_ea27d_row5_col0, #T_ea27d_row6_col0, #T_ea27d_row7_col0, #T_ea27d_row8_col0, #T_ea27d_row9_col0, #T_ea27d_row10_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ea27d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea27d_level0_row0" class="row_heading level0 row0" >Price</th>
#       <td id="T_ea27d_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row1" class="row_heading level0 row1" >VehicleType</th>
#       <td id="T_ea27d_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row2" class="row_heading level0 row2" >RegistrationYear</th>
#       <td id="T_ea27d_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row3" class="row_heading level0 row3" >Gearbox</th>
#       <td id="T_ea27d_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row4" class="row_heading level0 row4" >Power</th>
#       <td id="T_ea27d_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row5" class="row_heading level0 row5" >Model</th>
#       <td id="T_ea27d_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row6" class="row_heading level0 row6" >Kilometer</th>
#       <td id="T_ea27d_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row7" class="row_heading level0 row7" >RegistrationMonth</th>
#       <td id="T_ea27d_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row8" class="row_heading level0 row8" >FuelType</th>
#       <td id="T_ea27d_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row9" class="row_heading level0 row9" >Brand</th>
#       <td id="T_ea27d_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea27d_level0_row10" class="row_heading level0 row10" >NotRepaired</th>
#       <td id="T_ea27d_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Let's save the names of the signs in a separate list

attributes = list(df)
attributes
# Out:
# ['Price',
#  'VehicleType',
#  'RegistrationYear',
#  'Gearbox',
#  'Power',
#  'Model',
#  'Kilometer',
#  'RegistrationMonth',
#  'FuelType',
#  'Brand',
#  'NotRepaired']

# %% [markdown]
# * Let's analyze each column more carefully. It is necessary to isolate each condition separately and look at the other signs to make a decision.

# %%
# Column Price
           
df.sort_values(['Price'], ascending=False)
# Out:
#         Price  VehicleType  RegistrationYear  Gearbox  Power     Model  \
# 285890  20000        sedan              2012  unknown    184       3er
# 212038  20000        sedan              2011     auto    265  c_klasse
# 166379  20000          bus              2014   manual    150     other
# 1586    20000        sedan              2014     auto    184      leon
# 321362  20000        sedan              2011     auto    265  c_klasse
# ...       ...          ...               ...      ...    ...       ...
# 187584      0  convertible              2004   manual    135    megane
# 99318       0        wagon              2001   manual    140     lybra
# 99319       0        small              1995  unknown      0     corsa
# 99331       0  convertible              1996   manual     75      golf
# 221533      0        small              1998   manual      0  seicento
#
#         Kilometer  RegistrationMonth  FuelType          Brand NotRepaired
# 285890     100000                  6  gasoline            bmw          no
# 212038      50000                 11  gasoline  mercedes_benz          no
# 166379      20000                 12    petrol           ford          no
# 1586        40000                  4  gasoline           seat          no
# 321362      50000                 11  gasoline  mercedes_benz          no
# ...           ...                ...       ...            ...         ...
# 187584     150000                  3    petrol        renault          no
# 99318      150000                  0  gasoline         lancia     unknown
# 99319      150000                  0    petrol           opel     unknown
# 99331       50000                  6   unknown     volkswagen          no
# 221533     150000                  0    petrol           fiat     unknown
#
# [354365 rows x 11 columns]

# %%
df.sort_values(['RegistrationYear'], ascending=False)
# Out:
#         Price VehicleType  RegistrationYear  Gearbox  Power    Model  \
# 151228      0     unknown              9999  unknown      0  unknown
# 326721     60     unknown              9999  unknown      0       c4
# 167937   1000     unknown              9999  unknown      0  unknown
# 306575    350     unknown              9999  unknown      0   kaefer
# 333484      0     unknown              9999  unknown      0  unknown
# ...       ...         ...               ...      ...    ...      ...
# 348826      1     unknown              1000  unknown   1000  unknown
# 323440     30     unknown              1000  unknown      0  unknown
# 55605     500     unknown              1000  unknown      0  unknown
# 183778    500     unknown              1000  unknown      0  unknown
# 151725    400     unknown              1000  unknown      0  unknown
#
#         Kilometer  RegistrationMonth FuelType           Brand NotRepaired
# 151228      10000                  7  unknown           mazda     unknown
# 326721      10000                  0  unknown         citroen     unknown
# 167937      10000                  0  unknown           mazda     unknown
# 306575      10000                  1  unknown      volkswagen     unknown
# 333484      10000                  0  unknown             bmw     unknown
# ...           ...                ...      ...             ...         ...
# 348826     150000                  0  unknown  sonstige_autos     unknown
# 323440       5000                  0  unknown            audi     unknown
# 55605        5000                  0  unknown         citroen         yes
# 183778       5000                  1  unknown  sonstige_autos     unknown
# 151725       5000                  0  unknown   mercedes_benz     unknown
#
# [354365 rows x 11 columns]

# %%
df.sort_values(['Power'], ascending=False)
# Out:
#         Price VehicleType  RegistrationYear  Gearbox  Power    Model  \
# 219583   4300       coupe              1999     auto  20000      clk
# 299177   1500       wagon              1997   manual  19312      5er
# 114106   9999       sedan              2006   manual  19211      1er
# 132485   2100       wagon              2001   manual  19208      5er
# 63986    3250       sedan              2001     auto  17932    omega
# ...       ...         ...               ...      ...    ...      ...
# 115725    650       small              1998     auto      0    micra
# 264237   2600       wagon              1988   manual      0      601
# 264230    550     unknown              2000  unknown      0  unknown
# 264229   6500       small              1993   manual      0     golf
# 0         480     unknown              1993   manual      0     golf
#
#         Kilometer  RegistrationMonth  FuelType          Brand NotRepaired
# 219583     150000                  1    petrol  mercedes_benz          no
# 299177     150000                  1   unknown            bmw          no
# 114106     125000                  0  gasoline            bmw     unknown
# 132485     150000                  5   unknown            bmw         yes
# 63986      150000                  6    petrol           opel     unknown
# ...           ...                ...       ...            ...         ...
# 115725     150000                  4    petrol         nissan          no
# 264237     150000                  0    petrol        trabant          no
# 264230       5000                  0    petrol     volkswagen     unknown
# 264229     150000                 11  gasoline     volkswagen     unknown
# 0          150000                  0    petrol     volkswagen     unknown
#
# [354365 rows x 11 columns]

# %%
df.sort_values(['Kilometer'], ascending=False)
# Out:
#         Price VehicleType  RegistrationYear  Gearbox  Power    Model  \
# 0         480     unknown              1993   manual      0     golf
# 213204   3200       wagon              2005   manual    116      3er
# 213213   2799       sedan              1995   manual    150       a4
# 213212    550       sedan              1996     auto     90  carisma
# 213209    100     unknown              1995   manual     90     golf
# ...       ...         ...               ...      ...    ...      ...
# 14862    6500         bus              2005  unknown      0   touran
# 173477    750       small              2002   manual     70    grand
# 179744   3000       sedan              1996   manual    170      5er
# 206570   6399       wagon              2007   manual    140  transit
# 119527  11990       small              2016   manual     94    swift
#
#         Kilometer  RegistrationMonth  FuelType       Brand NotRepaired
# 0          150000                  0    petrol  volkswagen     unknown
# 213204     150000                  5  gasoline         bmw          no
# 213213     150000                  9    petrol        audi          no
# 213212     150000                 11    petrol  mitsubishi          no
# 213209     150000                  4    petrol  volkswagen         yes
# ...           ...                ...       ...         ...         ...
# 14862        5000                  0  gasoline  volkswagen     unknown
# 173477       5000                  8    petrol      suzuki          no
# 179744       5000                 10    petrol         bmw          no
# 206570       5000                  3  gasoline        ford     unknown
# 119527       5000                  3    petrol      suzuki          no
#
# [354365 rows x 11 columns]

# %% [markdown]
# * Column **Price**."0" values are clearly incorrect. If they wanted to give the car as a gift, it wouldn't be here. We remove them, they will not help us in the forecast.
# * Column **registrationyear**. All values older than 1960 can be removed, all values older than 2021 are the same. If the car is older than 1960, it is either junk, for which you need to pay extra when recycling, or a rare car. Rarities are sold at their auctions. It is very difficult to guess the price. Sort by condition.
# * Column **Power**. "0" power values cannot be and anything over 1000 is also incorrect. We're cleaning it up.
# * Column **Kilometer**. Everything is fine here.
# * General conclusion - sort the dataframe by conditions.

# %%
# Sort the dataframe by conditions

df = df.query('0 < Price and 1960 < RegistrationYear < 2021 and 0 < Power < 1000 and Price > 500')
df
# Out:
#         Price  VehicleType  RegistrationYear Gearbox  Power        Model  \
# 1       18300        coupe              2011  manual    190      unknown
# 2        9800          suv              2004    auto    163        grand
# 3        1500        small              2001  manual     75         golf
# 4        3600        small              2008  manual     69        fabia
# 5         650        sedan              1995  manual    102          3er
# ...       ...          ...               ...     ...    ...          ...
# 354357   5250      unknown              2016    auto    150          159
# 354358   3200        sedan              2004  manual    225         leon
# 354362   1199  convertible              2000    auto    101       fortwo
# 354363   9200          bus              1996  manual    102  transporter
# 354364   3400        wagon              2002  manual    100         golf
#
#         Kilometer  RegistrationMonth  FuelType       Brand NotRepaired
# 1          125000                  5  gasoline        audi         yes
# 2          125000                  8  gasoline        jeep     unknown
# 3          150000                  6    petrol  volkswagen          no
# 4           90000                  7  gasoline       skoda          no
# 5          150000                 10    petrol         bmw         yes
# ...           ...                ...       ...         ...         ...
# 354357     150000                 12   unknown  alfa_romeo          no
# 354358     150000                  5    petrol        seat         yes
# 354362     125000                  3    petrol       smart          no
# 354363     150000                  3  gasoline  volkswagen          no
# 354364     150000                  6  gasoline  volkswagen     unknown
#
# [284570 rows x 11 columns]

# %% [markdown]
# * 69795 - we have removed so many rows from our selection by applying the agreed conditions.

# %%
# Let's analyze the correlation of features, output the correlation matrix

cor_m = df[['Price', 'RegistrationYear', 'Power', 'Kilometer', 'RegistrationMonth']].corr()
cor_m.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_52190_row0_col0, #T_52190_row1_col1, #T_52190_row2_col2, #T_52190_row3_col3, #T_52190_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_52190_row0_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_52190_row0_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_52190_row0_col3, #T_52190_row3_col0, #T_52190_row3_col1, #T_52190_row3_col4, #T_52190_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_52190_row0_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_52190_row1_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_52190_row1_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_52190_row1_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_52190_row1_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_52190_row2_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_52190_row2_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_52190_row2_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_52190_row2_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_52190_row3_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_52190_row4_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_52190_row4_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_52190_row4_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# </style>
# <table id="T_52190_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Price</th>
#       <th class="col_heading level0 col1" >RegistrationYear</th>
#       <th class="col_heading level0 col2" >Power</th>
#       <th class="col_heading level0 col3" >Kilometer</th>
#       <th class="col_heading level0 col4" >RegistrationMonth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52190_level0_row0" class="row_heading level0 row0" >Price</th>
#       <td id="T_52190_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_52190_row0_col1" class="data row0 col1" >0.42</td>
#       <td id="T_52190_row0_col2" class="data row0 col2" >0.48</td>
#       <td id="T_52190_row0_col3" class="data row0 col3" >-0.39</td>
#       <td id="T_52190_row0_col4" class="data row0 col4" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_52190_level0_row1" class="row_heading level0 row1" >RegistrationYear</th>
#       <td id="T_52190_row1_col0" class="data row1 col0" >0.42</td>
#       <td id="T_52190_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_52190_row1_col2" class="data row1 col2" >0.08</td>
#       <td id="T_52190_row1_col3" class="data row1 col3" >-0.27</td>
#       <td id="T_52190_row1_col4" class="data row1 col4" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_52190_level0_row2" class="row_heading level0 row2" >Power</th>
#       <td id="T_52190_row2_col0" class="data row2 col0" >0.48</td>
#       <td id="T_52190_row2_col1" class="data row2 col1" >0.08</td>
#       <td id="T_52190_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_52190_row2_col3" class="data row2 col3" >0.12</td>
#       <td id="T_52190_row2_col4" class="data row2 col4" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_52190_level0_row3" class="row_heading level0 row3" >Kilometer</th>
#       <td id="T_52190_row3_col0" class="data row3 col0" >-0.39</td>
#       <td id="T_52190_row3_col1" class="data row3 col1" >-0.27</td>
#       <td id="T_52190_row3_col2" class="data row3 col2" >0.12</td>
#       <td id="T_52190_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_52190_row3_col4" class="data row3 col4" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_52190_level0_row4" class="row_heading level0 row4" >RegistrationMonth</th>
#       <td id="T_52190_row4_col0" class="data row4 col0" >0.05</td>
#       <td id="T_52190_row4_col1" class="data row4 col1" >0.01</td>
#       <td id="T_52190_row4_col2" class="data row4 col2" >0.03</td>
#       <td id="T_52190_row4_col3" class="data row4 col3" >-0.01</td>
#       <td id="T_52190_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * The correlation matrix shows that the year of manufacture and power correlate with the price - which is reasonable.

# %% [markdown]
# ### Working with categorical features

# %% [markdown]
# We will use gradient boosting. So let's encode all the data of the object type into numeric values.
# * categorical features are in the columns: 'Vehicle Type', 'Gearbox', 'Model', 'FuelType', 'Brand'. We will encode them using the Label Encoder.
# * the column **Not Repaired** will be encoded into values (0,1)

# %%
df['NotRepaired'].unique()
# Out:
# array(['yes', 'unknown', 'no'], dtype=object)

# %%
# Encoding a binary attribute

df['NotRepaired'] = df['NotRepaired'].map({'no': 0, 'unknown': 0, 'yes': 1})

# %%
# Let's create a function for encoding categorical features into numeric values

def get_encode(data, columns):
    encode_df = data.copy()
    enc = OrdinalEncoder()
    encode_df[columns]=enc.fit_transform(encode_df[columns])
    encode_df[columns] = encode_df[columns].astype('int')
    display(encode_df.head())
    return encode_df

# %%
# Let's start the function in operation

encode_df = get_encode(df, ['VehicleType', 'Gearbox', 'Model', 'FuelType', 'Brand'])
# Out:
#    Price  VehicleType  RegistrationYear  Gearbox  Power  Model  Kilometer  \
# 1  18300            2              2011        1    190    227     125000
# 2   9800            6              2004        0    163    117     125000
# 3   1500            5              2001        1     75    116     150000
# 4   3600            5              2008        1     69    101      90000
# 5    650            4              1995        1    102     11     150000
#
#    RegistrationMonth  FuelType  Brand  NotRepaired
# 1                  5         2      1            1
# 2                  8         2     14            0
# 3                  6         6     38            0
# 4                  7         2     31            0
# 5                 10         6      2            1

# %%
# Let's analyze the correlation of features, output the correlation matrix

cor_m = encode_df.corr()
cor_m.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_57f2b_row0_col0, #T_57f2b_row1_col1, #T_57f2b_row2_col2, #T_57f2b_row3_col3, #T_57f2b_row4_col4, #T_57f2b_row5_col5, #T_57f2b_row6_col6, #T_57f2b_row7_col7, #T_57f2b_row8_col8, #T_57f2b_row9_col9, #T_57f2b_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_57f2b_row0_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_57f2b_row0_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_57f2b_row0_col3, #T_57f2b_row4_col1, #T_57f2b_row7_col10 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_57f2b_row0_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_57f2b_row0_col5, #T_57f2b_row3_col1, #T_57f2b_row4_col7, #T_57f2b_row6_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_57f2b_row0_col6, #T_57f2b_row0_col8, #T_57f2b_row0_col10, #T_57f2b_row1_col5, #T_57f2b_row3_col4, #T_57f2b_row4_col3, #T_57f2b_row4_col9, #T_57f2b_row5_col1, #T_57f2b_row6_col0, #T_57f2b_row6_col2, #T_57f2b_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_57f2b_row0_col7, #T_57f2b_row7_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_57f2b_row0_col9, #T_57f2b_row8_col4, #T_57f2b_row10_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_57f2b_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_57f2b_row1_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_57f2b_row1_col3, #T_57f2b_row6_col3, #T_57f2b_row7_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_57f2b_row1_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_57f2b_row1_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_57f2b_row1_col7, #T_57f2b_row9_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_57f2b_row1_col8, #T_57f2b_row6_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_57f2b_row1_col9, #T_57f2b_row3_col2, #T_57f2b_row5_col2, #T_57f2b_row5_col4, #T_57f2b_row5_col8, #T_57f2b_row9_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_57f2b_row1_col10 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_57f2b_row2_col0, #T_57f2b_row5_col9 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_57f2b_row2_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_57f2b_row2_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_57f2b_row2_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_57f2b_row2_col5, #T_57f2b_row3_col0, #T_57f2b_row8_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_57f2b_row2_col6, #T_57f2b_row8_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_57f2b_row2_col7, #T_57f2b_row4_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_57f2b_row2_col8, #T_57f2b_row8_col1, #T_57f2b_row8_col2, #T_57f2b_row9_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_57f2b_row2_col9, #T_57f2b_row9_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_57f2b_row2_col10, #T_57f2b_row6_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_57f2b_row3_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_57f2b_row3_col6, #T_57f2b_row7_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_57f2b_row3_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_57f2b_row3_col8, #T_57f2b_row5_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_57f2b_row3_col9, #T_57f2b_row10_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_57f2b_row3_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_57f2b_row4_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_57f2b_row4_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_57f2b_row4_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_57f2b_row4_col6, #T_57f2b_row9_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_57f2b_row4_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_57f2b_row5_col0, #T_57f2b_row8_col9 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_57f2b_row5_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_57f2b_row5_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_57f2b_row5_col10 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_57f2b_row6_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_57f2b_row6_col7, #T_57f2b_row9_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_57f2b_row6_col9 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_57f2b_row6_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_57f2b_row7_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_57f2b_row7_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_57f2b_row7_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_57f2b_row7_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_57f2b_row7_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_57f2b_row7_col9, #T_57f2b_row9_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_57f2b_row8_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_57f2b_row8_col6, #T_57f2b_row10_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_57f2b_row8_col10 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_57f2b_row9_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_57f2b_row9_col5 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_57f2b_row9_col10, #T_57f2b_row10_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_57f2b_row10_col3, #T_57f2b_row10_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_57f2b_row10_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_57f2b_row10_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_57f2b_row10_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_57f2b_row10_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_57f2b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Price</th>
#       <th class="col_heading level0 col1" >VehicleType</th>
#       <th class="col_heading level0 col2" >RegistrationYear</th>
#       <th class="col_heading level0 col3" >Gearbox</th>
#       <th class="col_heading level0 col4" >Power</th>
#       <th class="col_heading level0 col5" >Model</th>
#       <th class="col_heading level0 col6" >Kilometer</th>
#       <th class="col_heading level0 col7" >RegistrationMonth</th>
#       <th class="col_heading level0 col8" >FuelType</th>
#       <th class="col_heading level0 col9" >Brand</th>
#       <th class="col_heading level0 col10" >NotRepaired</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57f2b_level0_row0" class="row_heading level0 row0" >Price</th>
#       <td id="T_57f2b_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_57f2b_row0_col1" class="data row0 col1" >-0.08</td>
#       <td id="T_57f2b_row0_col2" class="data row0 col2" >0.42</td>
#       <td id="T_57f2b_row0_col3" class="data row0 col3" >-0.25</td>
#       <td id="T_57f2b_row0_col4" class="data row0 col4" >0.48</td>
#       <td id="T_57f2b_row0_col5" class="data row0 col5" >-0.02</td>
#       <td id="T_57f2b_row0_col6" class="data row0 col6" >-0.39</td>
#       <td id="T_57f2b_row0_col7" class="data row0 col7" >0.05</td>
#       <td id="T_57f2b_row0_col8" class="data row0 col8" >-0.27</td>
#       <td id="T_57f2b_row0_col9" class="data row0 col9" >-0.10</td>
#       <td id="T_57f2b_row0_col10" class="data row0 col10" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_57f2b_level0_row1" class="row_heading level0 row1" >VehicleType</th>
#       <td id="T_57f2b_row1_col0" class="data row1 col0" >-0.08</td>
#       <td id="T_57f2b_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_57f2b_row1_col2" class="data row1 col2" >0.16</td>
#       <td id="T_57f2b_row1_col3" class="data row1 col3" >-0.02</td>
#       <td id="T_57f2b_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_57f2b_row1_col5" class="data row1 col5" >-0.13</td>
#       <td id="T_57f2b_row1_col6" class="data row1 col6" >0.07</td>
#       <td id="T_57f2b_row1_col7" class="data row1 col7" >-0.00</td>
#       <td id="T_57f2b_row1_col8" class="data row1 col8" >-0.05</td>
#       <td id="T_57f2b_ro

# %% [markdown]
# * The picture is stable. The correlation of the price with the year of manufacture and capacity is visible + high correlation of the model and brand. We can combine these columns into 1 attribute.

# %%
# Combining 2 columns into 1 feature (there is a high correlation)

df['Brand_Model']=df['Brand'] +'_'+ df['Model']
df=df.drop(['Brand','Model'],  axis=1)
df.head(3)
# Out:
#    Price VehicleType  RegistrationYear Gearbox  Power  Kilometer  \
# 1  18300       coupe              2011  manual    190     125000
# 2   9800         suv              2004    auto    163     125000
# 3   1500       small              2001  manual     75     150000
#
#    RegistrationMonth  FuelType  NotRepaired      Brand_Model
# 1                  5  gasoline            1     audi_unknown
# 2                  8  gasoline            0       jeep_grand
# 3                  6    petrol            0  volkswagen_golf

# %%
encode_df = get_encode(df, ['VehicleType', 'Gearbox', 'FuelType', 'Brand_Model'])
# Out:
#    Price  VehicleType  RegistrationYear  Gearbox  Power  Kilometer  \
# 1  18300            2              2011        1    190     125000
# 2   9800            6              2004        0    163     125000
# 3   1500            5              2001        1     75     150000
# 4   3600            5              2008        1     69      90000
# 5    650            4              1995        1    102     150000
#
#    RegistrationMonth  FuelType  NotRepaired  Brand_Model
# 1                  5         2            1           23
# 2                  8         2            0          119
# 3                  6         6            0          310
# 4                  7         2            0          267
# 5                 10         6            1           25

# %%
encode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284570 entries, 1 to 354364
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Price              284570 non-null  int64
#  1   VehicleType        284570 non-null  int64
#  2   RegistrationYear   284570 non-null  int64
#  3   Gearbox            284570 non-null  int64
#  4   Power              284570 non-null  int64
#  5   Kilometer          284570 non-null  int64
#  6   RegistrationMonth  284570 non-null  int64
#  7   FuelType           284570 non-null  int64
#  8   NotRepaired        284570 non-null  int64
#  9   Brand_Model        284570 non-null  int64
# dtypes: int64(10)
# memory usage: 23.9 MB

# %% [markdown]
# ### Output:
# * we analyzed the data, checked for duplicates, preprocessed, got rid of gaps and outliers;
# * preprocessing categorical features;
# * The data is ready to work

# %% [markdown]
# ## Model fitting

# %% [markdown]
# * Prepare samples

# %%
# Let's divide our dataset into training and target features

target = encode_df['Price']
features = encode_df.drop('Price', axis=1)

# %%
# Assign the variable **random_state**

rs=12345

# %%
target_train, target_test, features_train, features_test = train_test_split(target, features,
                                                                           test_size=.25,
                                                                           random_state=rs)

# %%
# Let's check the shape of the samples received

print('Features train', features_train.shape, target_train.shape)
print('Features test', features_test.shape, target_test.shape)
# Out:
# Features train (213427, 9) (213427,)
# Features test (71143, 9) (71143,)

# %%
# Let's normalize features_train features (all features of the training sample, with the exception of the target feature)

scaler = StandardScaler()
scaler.fit(features_train)
features_train = pd.DataFrame(scaler.transform(features_train), columns = features_train.columns)
features_test = scaler.transform(features_test)

# %% [markdown]
# ## Model analysis

# %% [markdown]
# ### Let's check the results of the basic models by cross-validation. Let's calculate the value of the RMSE metric for 3 basic regression models. Cross-validation on 5 blocks.

# %%
# Let's create a function to calculate the RMSE metric

def rmse_score(target, predictions):
    return mse(target, predictions)**.5

# %%
# Let's create a meter based on the RMSE metric calculation function

rmse = make_scorer(rmse_score, greater_is_better=False)

# %%
linear = LinearRegression()
linear_score = cross_val_score(linear, features, target, cv=5, scoring=rmse).mean()
linear_score
# Out:
# -2982.059671224179

# %%
tree = DecisionTreeRegressor()
tree_score = cross_val_score(tree, features, target, cv=5, scoring=rmse).mean()
tree_score
# Out:
# -2024.5862968957165

# %%
# %%time
forest = RandomForestRegressor(n_estimators=100)
forest_score = cross_val_score(forest, features, target, cv=5, scoring=rmse).mean()
forest_score
# Out:
# CPU times: user 5min 32s, sys: 4.2 s, total: 5min 36s
# Wall time: 5min 36s
# -1596.3619612625148

# %% [markdown]
# * The best result was shown by the **RandomForestRegressor model**

# %% [markdown]
# ### Let's select hyperparameters and train the model

# %% [markdown]
# #### DecisionTreeRegressor

# %%
# %%time
best_score = 5000
best_depth = 0
for depth in range(1, 16):
    tree_model = DecisionTreeRegressor(max_depth=depth, random_state=rs)
    tree_model_score = cross_val_score(tree_model, features_train, target_train,
                                     cv=5, scoring=rmse)
    if np.abs(tree_model_score.mean()) < np.abs(best_score):
        best_score_t = tree_model_score.mean()
        best_depth_t = depth
        best_tree_model = tree_model

print('Best depth:', best_depth_t)
print('RMSE:', best_score_t)
# Out:
# Best depth: 15
# RMSE: -1930.541234867934
# CPU times: user 21.1 s, sys: 20 ms, total: 21.1 s
# Wall time: 21.1 s

# %%
fit_time = datetime.datetime.now()
model_tree = DecisionTreeRegressor(max_depth=best_depth_t, random_state=rs)
model_tree.fit(features_train, target_train)
time_of_fit_tree = (datetime.datetime.now()-fit_time).seconds
predict_time = datetime.datetime.now()
predictions_tree = model_tree.predict(features_test)
time_of_predict_tree = (datetime.datetime.now()-predict_time).seconds
tree_rmse = rmse_score(target_test, predictions_tree)

print('Time of fit:', time_of_fit_tree, 'секунд.')
print('Time og predict:', time_of_predict_tree, 'секунд.')
print('RMSE:', tree_rmse)
# Out:
# Time of fit: 0 секунд.
# Time og predict: 0 секунд.
# RMSE: 1890.2267677046527

# %%
# Let's analyze the influence of factors on the target. Output by importance

importances = model_tree.feature_importances_
feature_list = list(features_train.columns)
feature_results = pd.DataFrame({'feature': feature_list,'importance': importances}).sort_values('importance',ascending = False).reset_index(drop=True)
feature_results.head(11)
# Out:
#              feature  importance
# 0   RegistrationYear    0.494152
# 1              Power    0.299829
# 2          Kilometer    0.088131
# 3        Brand_Model    0.055590
# 4        VehicleType    0.028704
# 5  RegistrationMonth    0.011101
# 6        NotRepaired    0.010539
# 7           FuelType    0.007213
# 8            Gearbox    0.004740

# %% [markdown]
# * The results are expected. Important factors are the year of registration and the power of the car.

# %% [markdown]
# #### RandomForestRegressor

# %%
# %%time 
best_score = 5000
best_est = 0
best_depth = 0
for est in range(90, 110, 10):
    for depth in range(13, 16):
        forest_model = RandomForestRegressor(max_depth=depth, n_estimators=est, random_state=rs)
        forest_model_score = cross_val_score(forest_model, features_train, target_train,
                                           cv=5, scoring=rmse)
        if np.abs(forest_model_score.mean()) < np.abs(best_score):
            best_score_f = forest_model_score.mean()
            best_depth_f = depth
            best_est_f = est

print('Best n_estimators:', best_est_f)
print('Best depth:', best_depth_f)
print('RMSE:', best_score_f)
# Out:
# Best n_estimators: 100
# Best depth: 15
# RMSE: -1660.9116288343969
# CPU times: user 14min 36s, sys: 568 ms, total: 14min 37s
# Wall time: 14min 36s

# %%
fit_time = datetime.datetime.now()
model_forest = RandomForestRegressor(n_estimators=best_est_f, max_depth=best_depth_f, random_state=rs)
model_forest.fit(features_train, target_train)
time_of_fit_forest = (datetime.datetime.now()-fit_time).seconds
predict_time = datetime.datetime.now()
predictions_forest = model_forest.predict(features_test)
time_of_predict_forest = (datetime.datetime.now()-predict_time).seconds
forest_rmse = rmse_score(target_test, predictions_forest)

print('Time of fit:', time_of_fit_forest, 'секунд.')
print('Time of predict:', time_of_predict_forest, 'секунд.')
print('RMSE:', forest_rmse)
# Out:
# Time of fit: 40 секунд.
# Time of predict: 1 секунд.
# RMSE: 1640.5297854209975

# %% [markdown]
# #### LinearRegression

# %%
fit_time = datetime.datetime.now()
model_linear = LinearRegression()
model_linear.fit(features_train, target_train)
time_of_fit_linear = (datetime.datetime.now()-fit_time).seconds
predict_time = datetime.datetime.now()
predictions_linear = model_linear.predict(features_test)
time_of_predict_linear = (datetime.datetime.now()-predict_time).seconds
linear_rmse = rmse_score(target_test, predictions_linear)

print('Time of fit:', time_of_fit_linear, 'секунд.')
print('Time of predict:', time_of_predict_linear, 'секунд.')
print('RMSE:', linear_rmse)
# Out:
# Time of fit: 0 секунд.
# Time of predict: 0 секунд.
# RMSE: 2983.847334368411

# %% [markdown]
# #### Gradient boosting LightGBM

# %%
# %%time 
best_score = 5000
best_est = 0
best_depth = 0
for est in range(80,100, 10):
    for depth in range(13, 15):
        light_model = LGBMRegressor(max_depth=depth, n_estimators=est, random_state=rs)
        light_model_score = cross_val_score(light_model, features_train, target_train,
                                           cv=5, scoring=rmse)
        if np.abs(light_model_score.mean()) < np.abs(best_score):
            best_score_l = light_model_score.mean()
            best_depth_l = depth
            best_est_l = est

print('Best n_estimators:', best_est_l)
print('Best depth:', best_depth_l)
print('RMSE:', best_score_l)
# Out:
# Best n_estimators: 90
# Best depth: 14
# RMSE: -1738.7029118911346
# CPU times: user 56.5 s, sys: 320 ms, total: 56.9 s
# Wall time: 15.4 s

# %%
fit_time = datetime.datetime.now()
model_light = LGBMRegressor(n_estimators=best_est_l, max_depth=best_depth_l, random_state=rs)
model_light.fit(features_train, target_train)
time_of_fit_light = (datetime.datetime.now()-fit_time).seconds
predict_time = datetime.datetime.now()
predictions_light = model_light.predict(features_test)
time_of_predict_light = (datetime.datetime.now()-predict_time).seconds
light_rmse = rmse_score(target_test, predictions_light)

print('Time of fit:', time_of_fit_light, 'секунд.')
print('Time of predict:', time_of_predict_light, 'секунд.')
print('RMSE:', light_rmse)
# Out:
# Time of fit: 0 секунд.
# Time of predict: 0 секунд.
# RMSE: 1738.060138683184

# %% [markdown]
# #### Let's analyze the models

# %%
# Создадим итоговую таблицу результатов

data = {'Model':['Linear Regression', 'Decision Tree', 'Random Forest', 'LightGBM'],
       'RMSE':[linear_rmse, tree_rmse, forest_rmse, light_rmse],
       'Fit Time':[time_of_fit_linear, time_of_fit_tree, time_of_fit_forest,
                       time_of_fit_light],
       'Predict Time':[time_of_predict_linear, time_of_predict_tree, time_of_predict_forest,
                       time_of_predict_light],
       'Parameters Selection Time':[0, 30, 5040, 1800]}

result_table = pd.DataFrame(data)
result_table
# Out:
#                Model         RMSE  Fit Time  Predict Time  \
# 0  Linear Regression  2983.847334         0             0
# 1      Decision Tree  1890.226768         0             0
# 2      Random Forest  1640.529785        40             1
# 3           LightGBM  1738.060139         0             0
#
#    Parameters Selection Time
# 0                          0
# 1                         30
# 2                       5040
# 3                       1800

# %%
# Let's analyze the influence of the model factors Random Forest

importances_forest_model = model_forest.feature_importances_
feature_list = list(features_train.columns)
feature_results = pd.DataFrame({'feature': feature_list,'importance': importances}).sort_values('importance',ascending = False).reset_index(drop=True)
feature_results.head(11)
# Out:
#              feature  importance
# 0   RegistrationYear    0.494152
# 1              Power    0.299829
# 2          Kilometer    0.088131
# 3        Brand_Model    0.055590
# 4        VehicleType    0.028704
# 5  RegistrationMonth    0.011101
# 6        NotRepaired    0.010539
# 7           FuelType    0.007213
# 8            Gearbox    0.004740

# %% [markdown]
# ## Summary: the Random Forest model showed the best result, but the model loses to everyone during training.  A close result was shown by the LightGBM model with a good result in terms of training time.
