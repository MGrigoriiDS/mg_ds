# %% [markdown]
# # **Прогнозирование эффективности обогащения концентрата золотосодержащей руды**

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Необходимо-подготовить-прототип-модели-машинного-обучения-для-«Цифры»." data-toc-modified-id="Необходимо-подготовить-прототип-модели-машинного-обучения-для-«Цифры».-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span>Необходимо подготовить прототип модели машинного обучения для «Цифры».</a></span></li><li><span><a href="#Необходимо-спрогнозировать-две-величины:" data-toc-modified-id="Необходимо-спрогнозировать-две-величины:-0.0.2"><span class="toc-item-num">0.0.2&nbsp;&nbsp;</span>Необходимо спрогнозировать две величины:</a></span></li></ul></li></ul></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных</a></span><ul class="toc-item"><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Параметры-этапов" data-toc-modified-id="Параметры-этапов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Параметры этапов</a></span></li><li><span><a href="#Наименование-признаков" data-toc-modified-id="Наименование-признаков-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Наименование признаков</a></span></li></ul></li><li><span><a href="#1.-Подготовка-данных" data-toc-modified-id="1.-Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>1. Подготовка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.1.-Откроем-файлы-и-изучим-их." data-toc-modified-id="1.1.-Откроем-файлы-и-изучим-их.-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>1.1. Откроем файлы и изучим их.</a></span></li><li><span><a href="#1.2.-Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Вычислим-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдем-MAE-между-расчётами-и-значением-признака.-Опишем-выводы." data-toc-modified-id="1.2.-Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Вычислим-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдем-MAE-между-расчётами-и-значением-признака.-Опишем-выводы.-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>1.2. Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между расчётами и значением признака. Опишем выводы.</a></span></li><li><span><a href="#1.3.-Проанализируем-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="1.3.-Проанализируем-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>1.3. Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span></li><li><span><a href="#1.4.-Проведем-предобработку-данных" data-toc-modified-id="1.4.-Проведем-предобработку-данных-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>1.4. Проведем предобработку данных</a></span></li></ul></li><li><span><a href="#Выводы-по-главе-1:" data-toc-modified-id="Выводы-по-главе-1:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выводы по главе 1:</a></span></li></ul></li><li><span><a href="#2.-Анализ-данных" data-toc-modified-id="2.-Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>2. Анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#2.1.-Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишем-выводы." data-toc-modified-id="2.1.-Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишем-выводы.-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишем выводы.</a></span></li><li><span><a href="#Выводы-по-главе-2.1:" data-toc-modified-id="Выводы-по-главе-2.1:-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Выводы по главе 2.1:</a></span></li><li><span><a href="#2.2.-Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="2.2.-Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>2.2. Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.</a></span></li><li><span><a href="#Вывод-по-главе-2.2:" data-toc-modified-id="Вывод-по-главе-2.2:-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Вывод по главе 2.2:</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#3.1.-Напишем-функцию-для-вычисления-итоговой-sMAPE.-Давайте-посмотрим-еще-раз-на-формулы:" data-toc-modified-id="3.1.-Напишем-функцию-для-вычисления-итоговой-sMAPE.-Давайте-посмотрим-еще-раз-на-формулы:-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>3.1. Напишем функцию для вычисления итоговой sMAPE. Давайте посмотрим еще раз на формулы:</a></span></li><li><span><a href="#3.2.-Обучим-разные-модели-и-оценим-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-Вам-пригодятся-формулы-метрик-качества:" data-toc-modified-id="3.2.-Обучим-разные-модели-и-оценим-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-Вам-пригодятся-формулы-метрик-качества:-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>3.2. Обучим разные модели и оценим их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы. Вам пригодятся формулы метрик качества:</a></span></li><li><span><a href="#Decision_tree_model" data-toc-modified-id="Decision_tree_model-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>Decision_tree_model</a></span></li><li><span><a href="#Random_forest_model" data-toc-modified-id="Random_forest_model-4.0.4"><span class="toc-item-num">4.0.4&nbsp;&nbsp;</span>Random_forest_model</a></span></li><li><span><a href="#Выводы-по-главе-3" data-toc-modified-id="Выводы-по-главе-3-4.0.5"><span class="toc-item-num">4.0.5&nbsp;&nbsp;</span>Выводы по главе 3</a></span></li></ul></li></ul></li><li><span><a href="#ИТОГИ:" data-toc-modified-id="ИТОГИ:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>ИТОГИ:</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# #### Необходимо подготовить прототип модели машинного обучения для «Цифры».
# * Компания разрабатывает решения для эффективной работы промышленных предприятий.
# * Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используем данные с параметрами добычи и очистки.
# * Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# #### Необходимо спрогнозировать две величины:
# * Эффективность обогащения чернового концентрата `rougher.output.recovery`
# * Эффективность обогащения финального концентрата `final.output.recovery`

# %% [markdown]
# ## Описание данных
# ### Технологический процесс
# * Rougher feed — исходное сырье
# * Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# * Xanthate **— ксантогенат (промотер, или активатор флотации);
# * Sulphate — сульфат (на данном производстве сульфид натрия);
# * Depressant — депрессант (силикат натрия).
# * Rougher process (англ. «грубый процесс») — флотация
# * Rougher tails — отвальные хвосты
# * Float banks — флотационная установка
# * Cleaner process — очистка
# * Rougher Au — черновой концентрат золота
# * Final Au — финальный концентрат золота
# ### Параметры этапов
# * air amount — объём воздуха
# * fluid levels — уровень жидкости
# * feed size — размер гранул сырья
# * feed rate — скорость подачи
# ### Наименование признаков
# Наименование признаков должно быть такое:
# * [этап].[тип_параметра].[название_параметра]
# * Пример: rougher.input.feed_ag
# * Возможные значения для блока [этап]:
# * rougher — флотация
# * primary_cleaner — первичная очистка
# * secondary_cleaner — вторичная очистка
# * final — финальные характеристики
# * Возможные значения для блока [тип_параметра]:
# * input — параметры сырья
# * output — параметры продукта
# * state — параметры, характеризующие текущее состояние этапа
# * calculation — расчётные характеристики

# %% [markdown]
# ## 1. Подготовка данных

# %%
# Загрузка библиотек

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.dummy import DummyRegressor
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# #### 1.1. Откроем файлы и изучим их.

# %%
# Напишем функцию для ознакомления с данными

def view(df):
    print(df.info())
    return df.head()

# %%
# df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
# df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
# df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')

# %%
# Прочитаем данные из csv

df_full = pd.read_csv('gold_recovery_full_new.csv')
df_train = pd.read_csv('gold_recovery_train_new.csv')
df_test = pd.read_csv('gold_recovery_test_new.csv')
display(view(df_full))
display(view(df_train))
display(view(df_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# #### 1.2. Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между расчётами и значением признака. Опишем выводы.

# %% [markdown]
# * C — доля золота в концентрате после флотации
# * F — доля золота в сырье/концентрате до флотации/очистки
# * T — доля золота в отвальных хвостах после флотации/очистки

# %%
# Напишем функцию дла рассчета МАЕ

def recovery(C, F, T):
    recovery = ((C*(F-T)) / (F*(C-T)))
    return recovery*100

df_train_test_mae['rougher.output.recovery_control'] = recovery(
    df_train['rougher.output.concentrate_au'],
    df_train['rougher.input.feed_au'],
    df_train['rougher.output.tail_au'])

x = df_train['rougher.output.recovery']
y = df_train_test_mae['rougher.output.recovery_control']
mae = (x - y).abs().mean()
print(f'mae - {mae :.2f}')
# Out:
# mae - 0.00

# %% [markdown]
# * Значение MAE близко к нулю, значит значение rougher.output.recovery рассчитано правильно.

# %% [markdown]
# #### 1.3. Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
# Выведем столбцы, которых нет в тестовой выборке

delta_columns = set(df_full.columns) - set(df_test.columns)
print(len(delta_columns))
delta_columns
# Out:
# 34
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Из тестового набора данных исключены целевые столбцы, оставлены только признаки. В тестовом наборе отсутствует 34 столбца.

# %% [markdown]
# #### 1.4. Проведем предобработку данных

# %%
# Проверим пропуски df_full

pd.DataFrame(round((df_full.isna().mean()*100),2)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
# Проверим пропуски df_train

pd.DataFrame(round((df_train.isna().mean()*100),2)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
# Проверим пропуски df_test

pd.DataFrame(round((df_test.isna().mean()*100),2)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_efd5f_row0_col0,#T_efd5f_row3_col0,#T_efd5f_row5_col0,#T_efd5f_row6_col0,#T_efd5f_row7_col0,#T_efd5f_row8_col0,#T_efd5f_row9_col0,#T_efd5f_row10_col0,#T_efd5f_row11_col0,#T_efd5f_row12_col0,#T_efd5f_row13_col0,#T_efd5f_row14_col0,#T_efd5f_row18_col0,#T_efd5f_row20_col0,#T_efd5f_row23_col0,#T_efd5f_row24_col0,#T_efd5f_row25_col0,#T_efd5f_row26_col0,#T_efd5f_row27_col0,#T_efd5f_row28_col0,#T_efd5f_row29_col0,#T_efd5f_row30_col0,#T_efd5f_row31_col0,#T_efd5f_row32_col0,#T_efd5f_row33_col0,#T_efd5f_row34_col0,#T_efd5f_row36_col0,#T_efd5f_row38_col0,#T_efd5f_row40_col0,#T_efd5f_row41_col0,#T_efd5f_row42_col0,#T_efd5f_row43_col0,#T_efd5f_row44_col0,#T_efd5f_row45_col0,#T_efd5f_row46_col0,#T_efd5f_row47_col0,#T_efd5f_row48_col0,#T_efd5f_row49_col0,#T_efd5f_row50_col0,#T_efd5f_row51_col0,#T_efd5f_row52_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_efd5f_row1_col0,#T_efd5f_row4_col0{
# ...

# %% [markdown]
# ### Выводы по главе 1:
#
# * Эффективность обогащения рассчитана верно. МАЕ между нашим рассчетом и значением признака одинаковы. Можем использовать данные из таблицы
# * Проанализированы признаки, недоступные в тестовой выборке. Эти данные отсутствуют на момент прогноза, т.к. замеряются и/или рассчитываются значительно позже output — параметры продукта
# * Данные изучены. Закончим предобработку ниже.

# %% [markdown]
# ## 2. Анализ данных

# %% [markdown]
# #### 2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишем выводы.

# %% [markdown]
# Данные о концентрации металлов содержатся в столбцах:
# - Начальная концентрация
#     - `rougher.input.feed_ag`
#     - `rougher.input.feed_au`
#     - `rougher.input.feed_pb`
# - После чернового процесса
#     - `rougher.output.concentrate_ag`
#     - `rougher.output.concentrate_pb`
#     - `rougher.output.concentrate_au`
# - После первой очистки
#     - `primary_cleaner.output.concentrate_ag`
#     - `primary_cleaner.output.concentrate_au`
#     - `primary_cleaner.output.concentrate_pb`
# - После второй очистки
#     - `final.output.concentrate_ag`
#     - `final.output.concentrate_pb`
#     - `final.output.concentrate_au`
#
# Построим графики для каждого металла с каждым этапом измерения концентрации.

# %%
concentrate_ag = ['rougher.input.feed_ag', 'rougher.output.concentrate_ag', 
                  'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag']
concentrate_au = ['rougher.input.feed_au', 'rougher.output.concentrate_au', 
                  'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']
concentrate_pb = ['rougher.input.feed_pb', 'rougher.output.concentrate_pb', 
                  'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']

# %%
def get_hist(data, columns, material):
    sns.set(style="white", palette="muted", color_codes=True)
    f, ax = plt.subplots(figsize=(12, 6), dpi= 80)
    plt.title('Концентрация '+ material+' на различных этапах обработки')

    sns.boxplot(data=data[columns], orient="h")

    ax.set_xlabel('Концентрация')
    ax.grid(True)
    plt.show()

# %%
get_hist(df_train, concentrate_ag, 'серебра')

# %%
get_hist(df_train, concentrate_pb, 'свинца')

# %%
get_hist(df_train, concentrate_au, 'золота')

# %% [markdown]
# #### Выводы по главе 2.1:
# Проанализировав графики можно сделать выводы о том, что:
# * среднее значение концентрации серебра(Ag) постепенно уменьшается
# * среднее значение концентрации свинца(Pb) увеличивается
# * среднее значение концентрации золота(Au) увеличивается

# %% [markdown]
# #### 2.2. Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %% [markdown]
# Сравним на гистограмме обучающую и тестовую выборку

# %%
plt.figure(figsize=[15,10])

plt.hist(df_train['rougher.input.feed_size'], bins=50, label = 'df_train', alpha=.4, density=True)
plt.hist(df_test['rougher.input.feed_size'], bins=50, label = 'df_test', alpha=.4, density=True)

plt.xlabel("Размер гранул сырья")
plt.ylabel("Частота встречаемости результатов")

plt.legend(loc='upper left')

plt.title("Гистограмма распределения размеров гранул сырья")
plt.show()

# %% [markdown]
# #### Вывод по главе 2.2:
# Визуально диаграммы очень похожи и близки к нормальному распределению. Можно сделать вывод, что распределения не сильно отличаются друг от друга. В целом размеры большинства частиц лежат в оптимальном интервале 40—100 мкм.

# %% [markdown]
# Изучим суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах. Рассмотрим эти параметры из общей выборки gold_recovery_full. Данные содержатся в столбцах: rougher.input.feed_ rougher.output.concentrate_ final.output.concentrate_ для каждого металла

# %%
df_full = df_full.dropna(subset=['final.output.recovery', 'rougher.output.recovery'])

# %%
total_concentrate = df_full.loc[:, (concentrate_ag+concentrate_au+concentrate_pb)]

# %%
def get_sum(stage):
    total_concentrate['total_'+stage] = (total_concentrate[stage+'_ag']+
                                       total_concentrate[stage+'_au']+
                                       total_concentrate[stage+'_pb'])

# %%
stages = ['rougher.input.feed', 'rougher.output.concentrate', 'final.output.concentrate']
for stage in stages:
    get_sum(stage)

# %%
total_concentrate.head()
# Out:
#    rougher.input.feed_ag  rougher.output.concentrate_ag  \
# 0               6.100378                      11.500771
# 1               6.161113                      11.615865
# 2               6.116455                      11.695753
# 3               6.043309                      11.915047
# 4               6.060915                      12.411054
#
#    primary_cleaner.output.concentrate_ag  final.output.concentrate_ag  \
# 0                               8.547551                     6.055403
# 1                               8.558743                     6.029369
# 2                               8.603505                     6.055926
# 3                               7.221879                     6.047977
# 4                               9.089428                     6.148599
#
#    rougher.input.feed_au  rougher.output.concentrate_au  \
# 0               6.486150                      19.793808
# 1               6.478583                      20.050975
# ...

# %%
sns.set(style="white", palette="muted", color_codes=True)
f, ax = plt.subplots(figsize=(12, 6), dpi= 80)
plt.title('Суммарная концентрация на каждом этапе')
sns.distplot(total_concentrate['total_rougher.input.feed'], label='сырьё', 
             hist_kws={'density':False}, kde_kws={'linewidth':1})
sns.distplot(total_concentrate['total_rougher.output.concentrate'], label='черновая очистка', 
             hist_kws={'density':False}, kde_kws={'linewidth':1})
sns.distplot(total_concentrate['total_final.output.concentrate'], label='финальный концентрат', 
             hist_kws={'density':False}, kde_kws={'linewidth':1})
ax.set_xlabel('Суммарная концентрация')
ax.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# На графике видно, что на двух их трёх этапах присутствуют нулевые значения суммарной концентрации металлов. Такие данные могут быть ошибочными, или не информативными. Удалим их из обеих выборок.

# %%
total_concentrate_filter = total_concentrate.loc[total_concentrate['total_rougher.input.feed']!= 0]
total_concentrate_filter = total_concentrate_filter.loc[total_concentrate_filter['total_rougher.output.concentrate']!= 0] 
total_concentrate_filter = total_concentrate_filter.loc[total_concentrate_filter['total_final.output.concentrate']!= 0]
print('Размер выборки до удаления', total_concentrate.shape)
print('Размер выборки после удаления', total_concentrate_filter.shape)
# Out:
# Размер выборки до удаления (19439, 15)
# Размер выборки после удаления (18949, 15)

# %%
train_index=(list(set(total_concentrate_filter.index).intersection(set(df_train.index))))
test_index=(list(set(total_concentrate_filter.index).intersection(set(df_test.index))))

# %%
df_train = df_train.loc[train_index,:]
df_test = df_test.loc[test_index,:]

# %%
print(df_train.shape)
df_test.shape
# Out:
# (13802, 87)
# (5173, 53)

# %%
sns.set(style="white", palette="muted", color_codes=True)
f, ax = plt.subplots(figsize=(12, 6), dpi= 80)
plt.title('Суммарная концентрация на каждом этапе')
sns.distplot(total_concentrate_filter['total_rougher.input.feed'], label='сырьё', 
             hist_kws={'density':False}, kde_kws={'linewidth':1})
sns.distplot(total_concentrate_filter['total_rougher.output.concentrate'], label='черновая очистка', 
             hist_kws={'density':False}, kde_kws={'linewidth':1})
sns.distplot(total_concentrate_filter['total_final.output.concentrate'], label='финальный концентрат', 
             hist_kws={'density':False}, kde_kws={'linewidth':1})
ax.set_xlabel('Суммарная концентрация')
ax.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# На графике видно, что мы убрали 0 значения.

# %%
# Удалим из обучающей выборки признаки, отсутствующие в тестовой части

df_train_select = df_train.drop(delta_columns, axis=1)

# %%
df_train_select['final.output.recovery'] = df_train['final.output.recovery']
df_train_select['rougher.output.recovery'] = df_train['rougher.output.recovery']

# %%
# Удалим пропуски в целевом признаке

df_train = df_train_select.dropna(subset=['final.output.recovery', 'rougher.output.recovery'])

# %%
df_train.shape
# Out:
# (13802, 55)

# %%
# Так как соседние по времени значения параметров должны быть похожи, заменим пропуски в данных на значения 
# недавно измеренных параметров при помощи метода ffill и проверим на пропуски

df_train = df_train.fillna(method='ffill')
pd.DataFrame(round((df_train.isna().mean()*100),2)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# Выполним то же самое для df_full и df_test

# %%
# Отсутствующие значения заполним ближайшими, по условию задачи

df_full = df_full.fillna(method='ffill')
df_test = df_test.fillna(method='ffill')

# %% [markdown]
# Приведем даты к датам и сделаем их индексами

# %%
df_train['date'] = pd.to_datetime(df_train['date'], format='%Y-%m-%d %H:%M:%S')
df_train = df_train.set_index(['date'])

# %%
df_test['date'] = pd.to_datetime(df_test['date'], format='%Y-%m-%d %H:%M:%S')
df_test = df_test.set_index(['date'])

# %%
df_full['date'] = pd.to_datetime(df_full['date'], format='%Y-%m-%d %H:%M:%S')
df_full = df_full.set_index(['date'])

# %%
# Проверим

print(df_full.info(), end='\n')
print(df_test.info(), end='\n')
print(df_train.info(), end='\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19439 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         19439 non-null  float64
#  1   final.output.concentrate_pb                         19439 non-null  float64
#  2   final.output.concentrate_sol                        19439 non-null  float64
#  3   final.output.concentrate_au                         19439 non-null  float64
#  4   final.output.recovery                               19439 non-null  float64
#  5   final.output.tail_ag                                19439 non-null  float64
#  6   final.output.tail_pb                                19439 non-null  float64
#  7   final.output.tail_sol                               19439 non-null  float64
# ...

# %% [markdown]
# ## Модель

# %% [markdown]
# #### 3.1. Напишем функцию для вычисления итоговой sMAPE. Давайте посмотрим еще раз на формулы:

# %%
# Создадим функцию для оценки sMAPE:

def sMAPE(predict, target):
    sMAPE = (abs(target - predict) / ((abs(target) + abs(predict)) / 2)).mean() * 100
    return sMAPE

score = make_scorer(sMAPE, greater_is_better=False)

# %% [markdown]
# #### 3.2. Обучим разные модели и оценим их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы. Вам пригодятся формулы метрик качества:

# %% [markdown]
# Выполним разметку на обучающие и целевые признаки **rougher.output.recovery и final.output.recovery**
# df_test

# %%
test_columns =  set(df_test.columns)

# %%
df_train_features = df_train.loc[:, test_columns]
df_train_features
# Out:
#                      primary_cleaner.state.floatbank8_c_level  \
# date
# 2016-01-15 00:00:00                               -498.666595
# 2016-01-15 01:00:00                               -499.315107
# 2016-01-15 02:00:00                               -500.870069
# 2016-01-15 03:00:00                               -500.727997
# 2016-01-15 04:00:00                               -500.888152
# ...                                                       ...
# 2018-08-18 06:59:59                               -399.363624
# 2018-08-18 07:59:59                               -401.195834
# 2018-08-18 08:59:59                               -399.988275
# 2018-08-18 09:59:59                               -399.521344
# 2018-08-18 10:59:59                               -400.586116
#
#                      secondary_cleaner.state.floatbank2_b_level  \
# date
# 2016-01-15 00:00:00                                 -501.406281
# 2016-01-15 01:00:00                                 -500.372428
# ...

# %%
df_train_target = df_train.loc[:, ['rougher.output.recovery', 'final.output.recovery']]
df_train_target
# Out:
#                      rougher.output.recovery  final.output.recovery
# date
# 2016-01-15 00:00:00                87.107763              70.541216
# 2016-01-15 01:00:00                86.843261              69.266198
# 2016-01-15 02:00:00                86.842308              68.116445
# 2016-01-15 03:00:00                87.226430              68.347543
# 2016-01-15 04:00:00                86.688794              66.927016
# ...                                      ...                    ...
# 2018-08-18 06:59:59                89.574376              73.755150
# 2018-08-18 07:59:59                87.724007              69.049291
# 2018-08-18 08:59:59                88.890579              67.002189
# 2018-08-18 09:59:59                89.858126              65.523246
# 2018-08-18 10:59:59                89.514960              70.281454
#
# [13802 rows x 2 columns]

# %%
df_train_features.head()
# Out:
#                      primary_cleaner.state.floatbank8_c_level  \
# date
# 2016-01-15 00:00:00                               -498.666595
# 2016-01-15 01:00:00                               -499.315107
# 2016-01-15 02:00:00                               -500.870069
# 2016-01-15 03:00:00                               -500.727997
# 2016-01-15 04:00:00                               -500.888152
#
#                      secondary_cleaner.state.floatbank2_b_level  \
# date
# 2016-01-15 00:00:00                                 -501.406281
# 2016-01-15 01:00:00                                 -500.372428
# 2016-01-15 02:00:00                                 -499.951928
# 2016-01-15 03:00:00                                 -499.848796
# 2016-01-15 04:00:00                                 -500.593614
#
#                      rougher.state.floatbank10_b_air  \
# date
# 2016-01-15 00:00:00                      1603.011353
# 2016-01-15 01:00:00                      1600.754587
# ...

# %% [markdown]
# Разделим features на rougher_features и final_features
# Для фильтрации по rougher используем метод .filter()

# %%
df_train_rougher_features = df_train_features.filter(regex='^rougher',axis=1)
df_train_rougher_features.head()
# Out:
#                      rougher.state.floatbank10_b_air  \
# date
# 2016-01-15 00:00:00                      1603.011353
# 2016-01-15 01:00:00                      1600.754587
# 2016-01-15 02:00:00                      1599.337330
# 2016-01-15 03:00:00                      1600.059442
# 2016-01-15 04:00:00                      1600.208824
#
#                      rougher.input.floatbank10_xanthate  \
# date
# 2016-01-15 00:00:00                            6.007990
# 2016-01-15 01:00:00                            6.005766
# 2016-01-15 02:00:00                            6.197377
# 2016-01-15 03:00:00                            6.203177
# 2016-01-15 04:00:00                            6.198826
#
#                      rougher.state.floatbank10_c_level  \
# date
# 2016-01-15 00:00:00                        -442.204468
# 2016-01-15 01:00:00                        -449.830646
# 2016-01-15 02:00:00                        -449.954491
# 2016-01-15 03:00:00                        -449.910497
# ...

# %% [markdown]
# **final_features** определяется разницей столбцов **df_train_features и df_train_rougher_features**

# %%
final_columns = set(df_train_features) - set(df_train_rougher_features)
df_train_final_features = df_train_features.loc[:, final_columns]
df_train_final_features.head()
# Out:
#                      primary_cleaner.state.floatbank8_c_level  \
# date
# 2016-01-15 00:00:00                               -498.666595
# 2016-01-15 01:00:00                               -499.315107
# 2016-01-15 02:00:00                               -500.870069
# 2016-01-15 03:00:00                               -500.727997
# 2016-01-15 04:00:00                               -500.888152
#
#                      secondary_cleaner.state.floatbank2_b_level  \
# date
# 2016-01-15 00:00:00                                 -501.406281
# 2016-01-15 01:00:00                                 -500.372428
# 2016-01-15 02:00:00                                 -499.951928
# 2016-01-15 03:00:00                                 -499.848796
# 2016-01-15 04:00:00                                 -500.593614
#
#                      secondary_cleaner.state.floatbank6_a_level  \
# date
# 2016-01-15 00:00:00                                 -605.841980
# ...

# %% [markdown]
# Выполним тоже самое для тестовой выборке **df_test:**

# %%
df_test_rougher_features = df_test.filter(regex='^rougher',axis=1)
df_test_rougher_features.head()
# Out:
#                      rougher.input.feed_ag  rougher.input.feed_pb  \
# date
# 2016-09-01 00:59:59              13.128569               5.636710
# 2016-09-01 01:59:59              13.036280               5.526065
# 2016-09-01 02:59:59              13.138412               5.426561
# 2016-09-01 03:59:59              12.400507               5.114758
# 2016-09-01 04:59:59              11.327427               4.767383
#
#                      rougher.input.feed_rate  rougher.input.feed_size  \
# date
# 2016-09-01 00:59:59               489.793655                62.710452
# 2016-09-01 01:59:59               490.104534                61.961163
# 2016-09-01 02:59:59               489.617969                66.903807
# 2016-09-01 03:59:59               476.618130                59.865919
# 2016-09-01 04:59:59               488.248117                63.315324
#
#                      rougher.input.feed_sol  rougher.input.feed_au  \
# date
# ...

# %%
df_test_final_features = df_test.loc[:, final_columns]
df_test_final_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5173 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.state.floatbank8_c_level    5173 non-null   float64
#  1   secondary_cleaner.state.floatbank2_b_level  5173 non-null   float64
#  2   secondary_cleaner.state.floatbank6_a_level  5173 non-null   float64
#  3   primary_cleaner.state.floatbank8_d_level    5173 non-null   float64
#  4   secondary_cleaner.state.floatbank5_b_air    5173 non-null   float64
#  5   secondary_cleaner.state.floatbank3_a_air    5173 non-null   float64
#  6   secondary_cleaner.state.floatbank4_b_air    5173 non-null   float64
#  7   secondary_cleaner.state.floatbank3_b_air    5173 non-null   float64
#  8   primary_cleaner.state.floatbank8_a_air      5173 non-null   float64
# ...

# %%
# Запишем df_test_full:

df_test_full = pd.DataFrame(data=df_full, index=df_test.index)
df_test_full.dropna(inplace=True)
df_test_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5173 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         5173 non-null   float64
#  1   final.output.concentrate_pb                         5173 non-null   float64
#  2   final.output.concentrate_sol                        5173 non-null   float64
#  3   final.output.concentrate_au                         5173 non-null   float64
#  4   final.output.recovery                               5173 non-null   float64
#  5   final.output.tail_ag                                5173 non-null   float64
#  6   final.output.tail_pb                                5173 non-null   float64
#  7   final.output.tail_sol                               5173 non-null   float64
# ...

# %% [markdown]
# Назначим целевые признаки в **df_test_target:**

# %%
df_test_target = df_test_full.loc[:, ['rougher.output.recovery', 'final.output.recovery']]
df_test_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5173 entries, 2016-09-01 00:59:59 to 2017-12-31 23:59:59
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   rougher.output.recovery  5173 non-null   float64
#  1   final.output.recovery    5173 non-null   float64
# dtypes: float64(2)
# memory usage: 121.2 KB

# %%
# Так как в features и target размеры ДатаФреймов разные из за 0 значений, приведем к одной размерности, 
# используя индексы df_test_full.index

df_test_rougher_features = pd.DataFrame(data=df_test_rougher_features, index=df_test_full.index)
df_test_final_features = pd.DataFrame(data=df_test_final_features, index=df_test_full.index)

# %%
# выведем размерности полученных переменных

var_list = [df_test_target, df_test_final_features, df_test_rougher_features, df_train_target, 
            df_train_final_features, df_train_rougher_features]
for var in var_list:
    print(var.shape)
# Out:
# (5173, 2)
# (5173, 30)
# (5173, 22)
# (13802, 2)
# (13802, 30)
# (13802, 22)

# %% [markdown]
# Для масштабирования признаков применим StandardScaler

# %%
def data_to_StandardScaler(data):
    sc = StandardScaler()
    data = sc.fit_transform(data)
    return data

# %%
df_train_rougher_features = data_to_StandardScaler(df_train_rougher_features)
df_train_final_features = data_to_StandardScaler(df_train_final_features)

df_test_rougher_features = data_to_StandardScaler(df_test_rougher_features)
df_test_final_features = data_to_StandardScaler(df_test_final_features)

# %% [markdown]
# Используем 3 модели для обучения, а также cross_val_predict для предсказаний модели при кросс-валидации:

# %% [markdown]
# Признаки:
# `df_train_rougher_features`
# `df_train_final_features`
# `df_test_rougher_features`
# `df_test_final_features`
#
# Целевые признаки:
# `df_train_target['rougher.output.recovery']`, `df_train_target['final.output.recovery']`
# `df_test_target['rougher.output.recovery']`, `df_test_target['final.output.recovery']`

# %%
# Сохраним модели в переменных

linear_model = LinearRegression()
decision_tree_model = DecisionTreeRegressor(random_state=12345)
random_forest_model = RandomForestRegressor(random_state=12345)

# %% [markdown]
# Для подбора гиперпараметров импортируем **GridSearchCV**, для кросс-валидации при подборе гиперпараметров **ShuffleSplit**.
# Вызовем гиперпараметры модели, используя `.get_params().keys()`:

# %% [markdown]
# #### Decision_tree_model

# %%
decision_tree_model.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'random_state', 'splitter'])

# %%
# Создадим словарь для решающего дерева

parameters_grid = {
    'max_depth' : range(1,6),
    'min_samples_leaf': range(1,6),
    'min_samples_split': range(1,6)
}

# %%
# Выберем парамеры кросс-валидации

cv = ShuffleSplit(n_splits=3, test_size=0.2, random_state=0)

# %%
# Создадим объект GridSearchCV

grid_cv = GridSearchCV(decision_tree_model, parameters_grid, scoring=score, cv=cv)

# %% [markdown]
# Запустим подбор параметров для **rougher_features**

# %%
# %%time
grid_cv.fit(df_train_rougher_features, df_train_target['rougher.output.recovery'])
# Out:
# Wall time: 1min 15s
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=0, test_size=0.2, train_size=None),
#              estimator=DecisionTreeRegressor(random_state=12345),
#              param_grid={'max_depth': range(1, 6),
#                          'min_samples_leaf': range(1, 6),
#                          'min_samples_split': range(1, 6)},
#              scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
# Выведем лучшие параметры

grid_cv.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=4, random_state=12345)

# %%
# Напечатаем лучшую оценку и параметры ее достижения

print(grid_cv.best_score_)
print(grid_cv.best_params_)
# Out:
# -9.644176972300423
# {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %% [markdown]
# Выполним тоже самое для **final_features**

# %%
# %%time
grid_cv.fit(df_train_final_features, df_train_target['final.output.recovery'])
# Out:
# Wall time: 54.7 s
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=0, test_size=0.2, train_size=None),
#              estimator=DecisionTreeRegressor(random_state=12345),
#              param_grid={'max_depth': range(1, 6),
#                          'min_samples_leaf': range(1, 6),
#                          'min_samples_split': range(1, 6)},
#              scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
print(grid_cv.best_score_)
print(grid_cv.best_params_)
# Out:
# -8.884668257201255
# {'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}

# %% [markdown]
# #### Random_forest_model

# %%
# Для случайного леса в параметры сетки возьмем n_estimators и max_depth

random_forest_model.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
parameters_grid = {
    'n_estimators' : range(5, 101, 5),
    'max_depth' : range(1, 6)
}

# %%
grid_cv = GridSearchCV(random_forest_model, parameters_grid, scoring=score, cv=cv)

# %% [markdown]
# Выполним подбор параметров для **rougher_features**

# %%
# %%time
grid_cv.fit(df_train_rougher_features, df_train_target['rougher.output.recovery'])
# Out:
# Wall time: 27min 32s
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=0, test_size=0.2, train_size=None),
#              estimator=RandomForestRegressor(random_state=12345),
#              param_grid={'max_depth': range(1, 6),
#                          'n_estimators': range(5, 101, 5)},
#              scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
print(grid_cv.best_score_)
print(grid_cv.best_params_)
# Out:
# -9.776817831994912
# {'max_depth': 5, 'n_estimators': 10}

# %% [markdown]
# Для **final_features**

# %%
# %%time
grid_cv.fit(df_train_final_features, df_train_target['final.output.recovery'])
# Out:
# Wall time: 32min 15s
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=0, test_size=0.2, train_size=None),
#              estimator=RandomForestRegressor(random_state=12345),
#              param_grid={'max_depth': range(1, 6),
#                          'n_estimators': range(5, 101, 5)},
#              scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
print(grid_cv.best_score_)
print(grid_cv.best_params_)
# Out:
# -8.513702917251868
# {'max_depth': 5, 'n_estimators': 90}

# %% [markdown]
# Полученные значения гиперпараметров будем использовать для моделей при вычисления итоговой метрики sMAPE

# %%
# Используем функцию для вычисления sMAPE

def sMAPE(predict, target):
    sMAPE = (abs(target - predict) / ((abs(target) + abs(predict)) / 2)).mean() * 100
    return sMAPE

# %% [markdown]
# Напишем 2 функции:
# - train_cross_val_predicts_and_total_sMAPE(model) - для проверки на обучающей выборке
# - test_predicts_and_total_sMAPE(model) - для проверки лучшей модели на тестовой выборке

# %%
def train_cross_val_predicts_and_total_sMAPE(model):
    rouger_predict = cross_val_predict(model, df_train_rougher_features, df_train_target['rougher.output.recovery'], cv=3)
    final_predict = cross_val_predict(model, df_train_final_features, df_train_target['final.output.recovery'], cv=3)
    rouger_sMAPE = sMAPE(rouger_predict, df_train_target['rougher.output.recovery'])
    final_sMAPE = sMAPE(final_predict, df_train_target['final.output.recovery'])
    total_sMAPE = .25 * rouger_sMAPE + .75 * final_sMAPE
    print('sMAPE для rougher.output.recovery:', rouger_sMAPE)
    print('sMAPE для final.output.recovery:', final_sMAPE)
    print('Итоговое sMAPE:', total_sMAPE)
    return

# %%
def test_predicts_and_total_sMAPE(model):
    model.fit(df_train_rougher_features, df_train_target['rougher.output.recovery'])
    rouger_predict = model.predict(df_test_rougher_features)
    
    model.fit(df_train_final_features, df_train_target['final.output.recovery'])
    final_predict = model.predict(df_test_final_features)
    
    rouger_sMAPE = sMAPE(rouger_predict, df_test_target['rougher.output.recovery'])
    final_sMAPE = sMAPE(final_predict, df_test_target['final.output.recovery'])
    total_sMAPE = .25 * rouger_sMAPE + .75 * final_sMAPE
    print('sMAPE для rougher.output.recovery: {:.2f} %'.format(rouger_sMAPE))
    print('sMAPE для final.output.recovery: {:.2f} %'.format(final_sMAPE))
    print('Итоговое sMAPE: {:.2f} %'.format(total_sMAPE))
    return rouger_predict, final_predict

# %%
# Посчитаем для Линейной Регрессии

train_cross_val_predicts_and_total_sMAPE(linear_model)
# Out:
# sMAPE для rougher.output.recovery: 16.417280652014387
# sMAPE для final.output.recovery: 12.010662084828933
# Итоговое sMAPE: 13.112316726625295

# %% [markdown]
# Посчитаем для **DecisionTreeRegressor** в 2-х вариантах:

# %%
# 1

decision_tree_model_1 = DecisionTreeRegressor(max_depth=5, min_samples_leaf=4,min_samples_split=2, random_state=12345)
train_cross_val_predicts_and_total_sMAPE(decision_tree_model_1)
# Out:
# sMAPE для rougher.output.recovery: 17.016519022505825
# sMAPE для final.output.recovery: 13.418966156964673
# Итоговое sMAPE: 14.318354373349962

# %%
# 2

decision_tree_model_2 = DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=2, random_state=12345)
train_cross_val_predicts_and_total_sMAPE(decision_tree_model_2)
# Out:
# sMAPE для rougher.output.recovery: 17.0624439400901
# sMAPE для final.output.recovery: 13.729236069527891
# Итоговое sMAPE: 14.562538037168443

# %% [markdown]
# Для **RandomForestRegressor**:

# %%
# 1

random_forest_model_1 = RandomForestRegressor(max_depth=5, n_estimators=10, random_state=12345)
train_cross_val_predicts_and_total_sMAPE(random_forest_model_1)
# Out:
# sMAPE для rougher.output.recovery: 13.468609430347447
# sMAPE для final.output.recovery: 13.633230883234582
# Итоговое sMAPE: 13.592075520012799

# %%
# 2

random_forest_model_2 = RandomForestRegressor(max_depth=5, n_estimators=90, random_state=12345)
train_cross_val_predicts_and_total_sMAPE(random_forest_model_2)
# Out:
# sMAPE для rougher.output.recovery: 13.67867515730398
# sMAPE для final.output.recovery: 13.475508699880715
# Итоговое sMAPE: 13.526300314236531

# %% [markdown]
# Лучшие результаты показала модель случайного леса **LinearRegression**.
# Проверим модель **LinearRegression на тестовой выборке:**

# %%
rouger_predict, final_predict = test_predicts_and_total_sMAPE(linear_model)
# Out:
# sMAPE для rougher.output.recovery: 14.40 %
# sMAPE для final.output.recovery: 10.78 %
# Итоговое sMAPE: 11.69 %

# %% [markdown]
# Напишем функцию final_deviation_compare для сравнения распределений

# %%
def final_deviation_compare(df1, df2):
    plt.figure(figsize=(17,5))
    sns.distplot(df1, color='g');
    sns.distplot(df2, color='b').set(xlabel='Значения', ylabel='Плотность частоты', title='Распределение предсказаний и реальных значений');

# %% [markdown]
# Построим распределения предсказаний и реальных значений для **этапа флотации:**

# %%
final_deviation_compare(rouger_predict, df_test_target['rougher.output.recovery'])

# %% [markdown]
# Предсказание эффективности обогащения чернового концентрата неидеальны.

# %% [markdown]
# И для **финального обогащения:**

# %%
final_deviation_compare(final_predict, df_test_target['final.output.recovery'])

# %% [markdown]
# Графики показывают, что модель хорошо справляется с предсказаниями эффективности обогащения финального концентрата.

# %% [markdown]
# * sMAPE для rougher.output.recovery(симметричное среднее абсолютное процентное отклонение для чернового концентрата)-14,4 %
# * sMAPE для final.output.recovery(симметричное среднее абсолютное процентное отклонение для финального концентрата)-10,78 %
# * Итоговое sMAPE: 11.69 %
# Признаков для обучения чернового концентрата меньше, чем для финального. Возможно, что это повлияло на результат

# %% [markdown]
# Для проверки модели на адекватность сравним ее с моделью случайных значений.
# Для этого воспользуемся DummyRegressor.

# %%
dummy_model = (DummyRegressor(strategy="mean"))

# %% [markdown]
# Посчитаем итоговое sMAPE для такой модели:

# %%
test_predicts_and_total_sMAPE(dummy_model)
# Out:
# sMAPE для rougher.output.recovery: 10.41 %
# sMAPE для final.output.recovery: 10.26 %
# Итоговое sMAPE: 10.30 %
# (array([82.74855401, 82.74855401, 82.74855401, ..., 82.74855401,
#         82.74855401, 82.74855401]),
#  array([66.52719785, 66.52719785, 66.52719785, ..., 66.52719785,
#         66.52719785, 66.52719785]))

# %% [markdown]
# Наша мадель LinearRegression показала следующие метрики: sMAPE для rougher.output.recovery: 14.40 %;  sMAPE для final.output.recovery: 10.78 %; Итоговое sMAPE: 11.69 %. За счет низкого качества предсказания эффективности обогащения чернового концентрата, среднее значение sMAPE оказалось меньше, чем у модели DummyRegressor.

# %% [markdown]
# ####    Выводы по главе 3

# %% [markdown]
# Наилучший результат по метрике sMAPE показала Модель LinearRegression.
# Эффективность обогащения финального концентрата предсказывается значительно лучше, чем эффективность обогащения чернового концентрата.

# %% [markdown]
# ## ИТОГИ:

# %% [markdown]
# * Мы проверили, что эффективность обогащения рассчитана правильно. Вычислили её на обучающей выборке для признака rougher.output.recovery. Нашли MAE между расчётами и значением признака. Значение MAE близко к нулю, значит значение rougher.output.recovery рассчитано правильно.
# * Изначально из тестового набора данных были исключены целевые столбцы, оставлены только признаки. В тестовом наборе отсутствовало 34 столбца. Откорректировали.
# * Заполнили пропуски средним от указанных соседних значений, для этого воспользововались KNNImputer из sklearn.impute.
# * Проанализировали графики и сделали вывод, что:
# среднее значение концентрации серебра(Ag) постепенно уменьшается,
# среднее значение концентрации свинца(Pb) увеличивается,
# среднее значение концентрации золота(Au) увеличивается.
# * Сравнили распределения размеров гранул сырья на обучающей и тестовой выборках. Распределения допустимо отличаются друг от друга. Можно сделать вывод, что размеры гранул сырья близки.
# * Написали функцию для вычисления итогового sMAPE.
# * **Модель LinearRegression, показала лучший результат по итоговой метрике sMAPE на тестовой выборке. sMAPE = 11.69%.**
# * Модель можно использовать для предсказания коэффициента восстановления золота из золотосодержащей руды.
# * Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
